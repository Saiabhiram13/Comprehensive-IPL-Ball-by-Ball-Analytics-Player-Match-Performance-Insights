# %%
import pandas as pd
data1 = pd.read_csv("C:\\Users\\hp\\Downloads\\archive\\matches.csv")

# %%
df1 = pd.DataFrame(data1)
data2 = pd.read_csv("C:\\Users\\hp\\Downloads\\archive\\deliveries.csv")
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %% [markdown]
# merge_df = pd.merge(df1,df2,left_on ="id",right_on ="match_id",how = "inner")
# merge_df.shape[0]

# %%
merge_df[merge_df["season"] == "2016"]
# Out:
#             id season       city        date match_type player_of_match  \
# 122502  980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 122503  980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 122504  980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 122505  980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 122506  980901   2016     Mumbai  2016-04-09     League       AM Rahane
# ...        ...    ...        ...         ...        ...             ...
# 136593  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 136594  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 136595  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 136596  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 136597  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
#
#                         venue                        team1  \
# ...

# %%
data = df1[df1["city"] == "Mumbai"]
data
# Out:
#            id   season    city        date match_type player_of_match  \
# 3      335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 12     335994  2007/08  Mumbai  2008-04-27     League    AC Gilchrist
# 22     336004  2007/08  Mumbai  2008-05-04     League      SM Pollock
# 26     336008  2007/08  Mumbai  2008-05-07     League         A Nehra
# 35     336018  2007/08  Mumbai  2008-05-14     League   ST Jayasuriya
# ...       ...      ...     ...         ...        ...             ...
# 1048  1426263     2024  Mumbai  2024-04-11     League       JJ Bumrah
# 1052  1426267     2024  Mumbai  2024-04-14     League     M Pathirana
# 1074  1426289     2024  Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024  Mumbai  2024-05-06     League        SA Yadav
# 1088  1426305     2024  Mumbai  2024-05-17     League        N Pooran
#
#                            venue                        team1  \
# 3               Wankhede Stadium               Mumbai Indians
# ...

# %%
pd.merge(data,df2,left_on ="id",right_on ="match_id",how  ="inner")
# Out:
#             id   season    city        date match_type player_of_match  \
# 0       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 1       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 2       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 3       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 4       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# ...        ...      ...     ...         ...        ...             ...
# 41737  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41738  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41739  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41740  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41741  1426305     2024  Mumbai  2024-05-17     League        N Pooran
#
#                           venue                 team1  \
# 0              Wankhede Stadium        Mumbai Indians
# ...

# %%
data2 = df1[df1["winner"] == "Mumbai Indians"]
data2
# Out:
#            id   season     city        date  match_type player_of_match  \
# 15     335997  2007/08  Kolkata  2008-04-29      League   ST Jayasuriya
# 22     336004  2007/08   Mumbai  2008-05-04      League      SM Pollock
# 26     336008  2007/08   Mumbai  2008-05-07      League         A Nehra
# 35     336018  2007/08   Mumbai  2008-05-14      League   ST Jayasuriya
# 37     336021  2007/08   Mumbai  2008-05-16      League      SM Pollock
# ...       ...      ...      ...         ...         ...             ...
# 1021  1370351     2023  Chennai  2023-05-24  Eliminator   Akash Madhwal
# 1043  1422138     2024   Mumbai  2024-04-07      League      R Shepherd
# 1048  1426263     2024   Mumbai  2024-04-11      League       JJ Bumrah
# 1056  1426271     2024   Mohali  2024-04-18      League       JJ Bumrah
# 1078  1426293     2024   Mumbai  2024-05-06      League        SA Yadav
#
#                                                   venue  \
# ...

# %%
pd.merge(data2,df2,left_on ="id",right_on ="match_id",how="inner")
# Out:
#             id   season     city        date match_type player_of_match  \
# 0       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 1       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 2       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 3       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 4       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# ...        ...      ...      ...         ...        ...             ...
# 34624  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34625  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34626  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34627  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34628  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
#
#                           venue                  team1           team2  \
# ...

# %%
df1["method"].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data = df1[df1["method"] == 'D/L']

# %%
pd.merge(data,df2,left_on = "id",right_on ="match_id",how ="inner")
# Out:
#            id   season       city        date match_type   player_of_match  \
# 0      336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 1      336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 2      336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 3      336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# 4      336022  2007/08      Delhi  2008-05-17     League  DPMD Jayawardene
# ...       ...      ...        ...         ...        ...               ...
# 3641  1370353     2023  Ahmedabad  2023-05-29      Final         DP Conway
# 3642  1370353     2023  Ahmedabad  2023-05-29      Final         DP Conway
# 3643  1370353     2023  Ahmedabad  2023-05-29      Final         DP Conway
# 3644  1370353     2023  Ahmedabad  2023-05-29      Final         DP Conway
# 3645  1370353     2023  Ahmedabad  2023-05-29      Final         DP Conway
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df1
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
full = pd.merge(df1,df2,left_on ="id",right_on ="match_id",how = "inner")
full
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
full.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
full["super_over"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
data = full[["id","super_over"]]

# %%
data
# Out:
#              id super_over
# 0        335982          N
# 1        335982          N
# 2        335982          N
# 3        335982          N
# 4        335982          N
# ...         ...        ...
# 260915  1426312          N
# 260916  1426312          N
# 260917  1426312          N
# 260918  1426312          N
# 260919  1426312          N
#
# [260920 rows x 2 columns]

# %%
data1 = pd.merge(data,full,left_on ="id",right_on = "match_id",how ="inner")
data1

# %%
full.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df1['result'].unique()
# Out:
# array(['runs', 'wickets', 'tie', 'no result'], dtype=object)

# %%
data = df1[df1["result"] == "tie"]
data
# Out:
#           id   season       city        date match_type player_of_match  \
# 66    392190     2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121  2009/10    Chennai  2010-03-21     League        J Theron
# 328   598004     2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017     2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315     2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741     2015  Ahmedabad  2015-04-21     League        SE Marsh
# 610  1082625     2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365     2019      Delhi  2019-03-30     League         PP Shaw
# 746  1178426     2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493  2020/21        NaN  2020-09-20     League      MP Stoinis
# 765  1216547  2020/21        NaN  2020-09-28     League  AB de Villiers
# 790  1216512  2020/21  Abu Dhabi  2020-10-18     League     LH Ferguson
# ...

# %%
m_mi=df1[(df1['team1']=='Mumbai Indians') | (df1['team2']=='Mumbai Indians')]
mi_loss=m_mi[m_mi['winner']!="Mumbai Indians"]
mi_loss
q = df2[df2["bowler"] == "JJ Bumrah"]

# %%
pd.merge(mi_loss,q,left_on = "id",right_on = "match_id",how = "inner")
# Out:
#            id season       city        date match_type player_of_match  \
# 0      597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 1      597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 2      597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 3      597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 4      597999   2013  Bangalore  2013-04-04     League        CH Gayle
# ...       ...    ...        ...         ...        ...             ...
# 1518  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 1519  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 1520  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 1521  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 1522  1426298   2024    Kolkata  2024-05-11     League        CV Varun
#
#                       venue                        team1           team2  \
# ...

# %%
def create_column(x):
    if x == "Final":
        return 1
    else:
        return 0

# %%
df1["is_final"] = df1["match_type"].apply(create_column)

# %%
df1
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df2["matchup"] = df2['batter'] + "vs" + df2["bowler"]

# %%
df2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
def categorical_column(x):
    if x in [4,6,7]:
        return "Boundary"
    elif x == 0:
        return "Dot"
    else:
        return "other"

# %%
df2["run_type"] = df2["total_runs"].apply(categorical_column)

# %%
df2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
def pow_over(x):
    if x<=6:
        return "powerplay"
    else:
        return "other"

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'matchup', 'run_type'],
#       dtype='object')

# %%
df2["powerplay"] = df2["over"].apply(pow_over)

# %%
df2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %% [markdown]
# df2["innings"].unique()

# %%
df2['inning'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
def inning(x):
    if x == 1:
        return "1st innings"
    else:
        return "2nd innings"

# %%
df2["inning_type"] = df2["inning"].apply(inning)

# %%
df2
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
df1["match_label"]  = df1["season"] + " VS "+ df1["city"]

# %%
df1
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'is_final', 'match_label'],
#       dtype='object')

# %%
full.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data = df1[df1["season"] == "2016"]
pd.merge(data,df2,left_on = "id",right_on = "match_id",how = "inner")
# Out:
#            id season       city        date match_type player_of_match  \
# 0      980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 1      980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 2      980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 3      980901   2016     Mumbai  2016-04-09     League       AM Rahane
# 4      980901   2016     Mumbai  2016-04-09     League       AM Rahane
# ...       ...    ...        ...         ...        ...             ...
# 14091  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 14092  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 14093  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 14094  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
# 14095  981019   2016  Bangalore  2016-05-29      Final     BCJ Cutting
#
#                        venue                        team1  \
# ...

# %%
data = df1[df1["city"] == "Mumbai"]
pd.merge(data,df2,left_on = "id", right_on = "match_id",how ="inner")
# Out:
#             id   season    city        date match_type player_of_match  \
# 0       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 1       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 2       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 3       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 4       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# ...        ...      ...     ...         ...        ...             ...
# 41737  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41738  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41739  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41740  1426305     2024  Mumbai  2024-05-17     League        N Pooran
# 41741  1426305     2024  Mumbai  2024-05-17     League        N Pooran
#
#                           venue                 team1  \
# 0              Wankhede Stadium        Mumbai Indians
# ...

# %%
data = df1[df1["winner"] == "Mumbai Indians"]
pd.merge(data,df2,left_on = "id", right_on = "match_id",how ="inner")
# Out:
#             id   season     city        date match_type player_of_match  \
# 0       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 1       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 2       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 3       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 4       335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# ...        ...      ...      ...         ...        ...             ...
# 34624  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34625  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34626  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34627  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 34628  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
#
#                           venue                  team1           team2  \
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data =df1[["id","match_type","season"]]
data2 = df2[["match_id","total_runs"]]
data1 = data[data["match_type"] == "Final"]
data1
pd.merge(data1,data2,left_on = "id",right_on ="match_id",how = "inner")
# Out:
#            id match_type   season  match_id  total_runs
# 0      336040      Final  2007/08    336040           0
# 1      336040      Final  2007/08    336040           1
# 2      336040      Final  2007/08    336040           0
# 3      336040      Final  2007/08    336040           0
# 4      336040      Final  2007/08    336040           0
# ...       ...        ...      ...       ...         ...
# 4081  1426312      Final     2024   1426312           1
# 4082  1426312      Final     2024   1426312           1
# 4083  1426312      Final     2024   1426312           1
# 4084  1426312      Final     2024   1426312           1
# 4085  1426312      Final     2024   1426312           1
#
# [4086 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
data=df1[["id","toss_winner","winner"]]
data
# Out:
#            id                  toss_winner                       winner
# 0      335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 1      335983          Chennai Super Kings          Chennai Super Kings
# 2      335984             Rajasthan Royals             Delhi Daredevils
# 3      335985               Mumbai Indians  Royal Challengers Bangalore
# 4      335986              Deccan Chargers        Kolkata Knight Riders
# ...       ...                          ...                          ...
# 1090  1426307                 Punjab Kings          Sunrisers Hyderabad
# 1091  1426309          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  1426310             Rajasthan Royals             Rajasthan Royals
# 1093  1426311             Rajasthan Royals          Sunrisers Hyderabad
# 1094  1426312          Sunrisers Hyderabad        Kolkata Knight Riders
#
# [1095 rows x 3 columns]

# %%
df1[df1["toss_winner"] == df1["winner"]]
# Out:
#            id   season        city        date  match_type player_of_match  \
# 1      335983  2007/08  Chandigarh  2008-04-19      League      MEK Hussey
# 8      335990  2007/08   Hyderabad  2008-04-24      League       YK Pathan
# 10     335992  2007/08   Bangalore  2008-04-26      League       SR Watson
# 12     335994  2007/08      Mumbai  2008-04-27      League    AC Gilchrist
# 14     335996  2007/08   Bangalore  2008-04-28      League        MS Dhoni
# ...       ...      ...         ...         ...         ...             ...
# 1072  1426287     2024     Chennai  2024-05-01      League   Harpreet Brar
# 1073  1426288     2024   Hyderabad  2024-05-02      League         B Kumar
# 1075  1426290     2024   Bengaluru  2024-05-04      League  Mohammed Siraj
# 1078  1426293     2024      Mumbai  2024-05-06      League        SA Yadav
# 1092  1426310     2024   Ahmedabad  2024-05-22  Eliminator        R Ashwin
#
#                                                   venue  \
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
full = pd.merge(df1,df2,left_on ="id",right_on = "match_id",how = "inner")
full
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
full.groupby(["season","batter"])["total_runs"].sum().sort_values(ascending=False)
# Out:
# season  batter
# 2016    V Kohli           998
# 2023    Shubman Gill      923
# 2022    JC Buttler        894
# 2016    DA Warner         884
# 2013    CH Gayle          778
#                          ...
# 2012    S Nadeem            0
# 2019    S Lamichhane        0
#         S Kaul              0
# 2012    V Pratap Singh      0
# 2016    M Ashwin            0
# Name: total_runs, Length: 2617, dtype: int64

# %%
a = full[full["venue"] == "Eden Gardens"]
a.groupby(["bowler","venue"])["is_wicket"].sum().sort_values(ascending=False)
# Out:
# bowler           venue
# SP Narine        Eden Gardens    61
# PP Chawla        Eden Gardens    43
# AD Russell       Eden Gardens    29
# Shakib Al Hasan  Eden Gardens    26
# Kuldeep Yadav    Eden Gardens    23
#                                  ..
# V Shankar        Eden Gardens     0
# V Kohli          Eden Gardens     0
# VS Malik         Eden Gardens     0
# Y Venugopal Rao  Eden Gardens     0
# Y Prithvi Raj    Eden Gardens     0
# Name: is_wicket, Length: 241, dtype: int64

# %%
data = df1[["id","toss_winner","toss_decision"]]
ans = data[data["toss_decision"] == "field"]
pd.merge(ans,df2,left_on = "id",right_on = "match_id",how = "inner").head(10)
# Out:
#        id                  toss_winner toss_decision  match_id  inning  \
# 0  335982  Royal Challengers Bangalore         field    335982       1
# 1  335982  Royal Challengers Bangalore         field    335982       1
# 2  335982  Royal Challengers Bangalore         field    335982       1
# 3  335982  Royal Challengers Bangalore         field    335982       1
# 4  335982  Royal Challengers Bangalore         field    335982       1
# 5  335982  Royal Challengers Bangalore         field    335982       1
# 6  335982  Royal Challengers Bangalore         field    335982       1
# 7  335982  Royal Challengers Bangalore         field    335982       1
# 8  335982  Royal Challengers Bangalore         field    335982       1
# 9  335982  Royal Challengers Bangalore         field    335982       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# ...

# %%
a = full[full["bowler"] =="JJ Bumrah"]
b = a[a["winner"] != "Mumbai Indians"]
b
# Out:
#              id season       city        date match_type player_of_match  \
# 76637    597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76638    597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76639    597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76640    597999   2013  Bangalore  2013-04-04     League        CH Gayle
# 76641    597999   2013  Bangalore  2013-04-04     League        CH Gayle
# ...         ...    ...        ...         ...        ...             ...
# 258196  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 258197  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 258198  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 258199  1426298   2024    Kolkata  2024-05-11     League        CV Varun
# 258200  1426298   2024    Kolkata  2024-05-11     League        CV Varun
#
#                         venue                        team1           team2  \
# ...

# %%
full.groupby(["","bowler"])["is_wicket"].sum().sort_values(ascending = False)
# Out:
# season   bowler
# 2021     HV Patel         35
# 2013     DJ Bravo         34
#          JP Faulkner      33
# 2020/21  K Rabada         32
# 2023     MM Sharma        31
#                           ..
# 2024     Suyash Sharma     0
# 2007/08  A Symonds         0
# 2024     TM Head           0
#          Tilak Varma       0
#          Umran Malik       0
# Name: is_wicket, Length: 1948, dtype: int64

# %%
full.groupby("bowler")["is_wicket"].sum().sort_values(ascending =False)
# Out:
# bowler
# YS Chahal          213
# DJ Bravo           207
# PP Chawla          201
# SP Narine          200
# R Ashwin           198
#                   ...
# Atharva Taide        0
# Aman Hakim Khan      0
# Sunny Gupta          0
# Sumit Kumar          0
# A Dananjaya          0
# Name: is_wicket, Length: 530, dtype: int64

# %%
df2["dismissal_kind"].unique()
# Out:
# array(['not out', 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field', 'retired out'], dtype=object)

# %%
df2["dismissal_kind"]=df2["dismissal_kind"].fillna("not out")

# %%
full.groupby(["season","bowler"])["is_wicket"].sum()
# Out:
# season   bowler
# 2007/08  A Kumble              8
#          A Mishra             11
#          A Nehra              14
#          A Nel                 1
#          A Symonds             0
#                               ..
# 2024     Washington Sundar     1
#          YS Chahal            19
#          Yash Dayal           16
#          Yash Thakur          12
#          Yudhvir Singh         1
# Name: is_wicket, Length: 1948, dtype: int64

# %%
data = df1[["id","season"]]

# %%
data1 = df2[["match_id","over","total_runs",'batting_team']]

# %%
res1 = pd.merge(data,data1,left_on ="id",right_on = "match_id",how ="inner")

# %%
res = res1[res1["season"] == "2017"]

# %%
res.groupby(["over","batting_team"])["total_runs"].mean()
# Out:
# over  batting_team
# 0     Delhi Daredevils               0.873563
#       Gujarat Lions                  1.202128
#       Kings XI Punjab                1.142857
#       Kolkata Knight Riders          1.280000
#       Mumbai Indians                 1.043478
#                                        ...
# 19    Kolkata Knight Riders          1.307692
#       Mumbai Indians                 1.938272
#       Rising Pune Supergiant         1.962500
#       Royal Challengers Bangalore    1.696970
#       Sunrisers Hyderabad            1.823529
# Name: total_runs, Length: 160, dtype: float64

# %%
a = df1[["id",'match_type']]

# %%
b = df2[["match_id","batter","total_runs"]]

# %%
res= pd.merge(a,b,left_on = "id",right_on = "match_id", how ="inner")

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
full = pd.merge(df1,df2,left_on = "id",right_on = "match_id",how = "inner")

# %%
a = full.groupby(["match_id","batter","over"])
b = a["batsman_runs"].sum()
c = b[b > 30]
c
# Out:
# match_id  batter      over
# 501247    CH Gayle    2       36
# 734047    SK Raina    5       32
# 1254076   RA Jadeja   19      36
# 1304060   PJ Cummins  15      34
# 1422138   R Shepherd  19      32
# Name: batsman_runs, dtype: int64

# %%
#For each batting team, compute total runs in each match.
a = full.groupby(["match_id","batting_team"])["total_runs"].sum().sort_values(ascending=False)
a
# Out:
# match_id  batting_team
# 1426268   Sunrisers Hyderabad            287
# 1422126   Sunrisers Hyderabad            277
# 1422134   Kolkata Knight Riders          272
# 1426273   Sunrisers Hyderabad            266
# 598027    Royal Challengers Bangalore    263
#                                         ...
# 1082617   Royal Challengers Bangalore     49
# 1082648   Kolkata Knight Riders           48
# 733993    Sunrisers Hyderabad             44
# 1178424   Rajasthan Royals                41
# 829813    Royal Challengers Bangalore      2
# Name: total_runs, Length: 2187, dtype: int64

# %%
#Identify matches where the winning team scored more runs in powerplay (overs 1–6).
a = full[full["over"] < 6]
a.groupby(["match_id","batting_team"])["total_runs"].sum().sort_values(ascending =False)
# Out:
# match_id  batting_team
# 1426273   Sunrisers Hyderabad            125
# 1426295   Sunrisers Hyderabad            107
# 1082636   Kolkata Knight Riders          105
# 734047    Chennai Super Kings            100
# 1426280   Punjab Kings                    93
#                                         ...
# 1175356   Chennai Super Kings             16
# 501245    Chennai Super Kings             15
# 392182    Rajasthan Royals                14
# 1304051   Sunrisers Hyderabad             14
# 829813    Royal Challengers Bangalore      2
# Name: total_runs, Length: 2187, dtype: int64

# %%
#For each match, find the bowler with the most dot balls.
a = full[full["batsman_runs"] == 0]
a.groupby("bowler")["batsman_runs"].count().sort_values(ascending=False)
# Out:
# bowler
# B Kumar            1872
# R Ashwin           1758
# SP Narine          1694
# PP Chawla          1402
# JJ Bumrah          1391
#                    ...
# RW Price              1
# LRPL Taylor           1
# Mandeep Singh         1
# Aman Hakim Khan       1
# AC Gilchrist          1
# Name: batsman_runs, Length: 520, dtype: int64

# %%
#Calculate the economy of each bowler per season

a=full.groupby(["bowler","match_id","season"])["total_runs"].sum()
b = full.groupby(["bowler","match_id","season"])["over"].count()
(a/b).sort_values(ascending = False)
# Out:
# bowler         match_id  season
# TK Curran      1136578   2018       6.000000
# YBK Jaiswal    1304059   2022       6.000000
# CK Kapugedera  336018    2007/08    5.200000
# AL Menaria     548349    2012       5.000000
# AJ Finch       598027    2013       4.833333
#                                       ...
# SK Raina       501249    2011       0.000000
# AC Gilchrist   598066    2013       0.000000
# DJ Bravo       1175356   2019       0.000000
# DP Nannes      501205    2011       0.000000
# AD Russell     1304054   2022       0.000000
# Length: 12978, dtype: float64

# %%
#Find bowlers who bowled maiden overs in a match.
a = full.groupby(["bowler","match_id"])["over"].nunique()
b = a[a["
# Out:
# bowler          match_id
# A Ashish Reddy  548329      2
#                 548341      4
#                 548346      3
#                 548348      3
#                 548352      2
#                            ..
# Z Khan          1082622     2
#                 1082635     4
#                 1082640     4
#                 1082642     4
#                 1082646     4
# Name: over, Length: 12978, dtype: int64

# %%
a = full[full["batsman_runs"] == 6]
a.groupby(["season","batting_team"])["batsman_runs"].count().sort_values(ascending =False)
# Out:
# season  batting_team
# 2024    Sunrisers Hyderabad            178
#         Royal Challengers Bengaluru    165
# 2018    Chennai Super Kings            145
# 2019    Kolkata Knight Riders          143
# 2016    Royal Challengers Bangalore    142
#                                       ...
# 2009    Delhi Daredevils                51
# 2011    Deccan Chargers                 48
# 2009    Rajasthan Royals                47
# 2011    Kolkata Knight Riders           45
#         Rajasthan Royals                42
# Name: batsman_runs, Length: 146, dtype: int64

# %%
full.groupby(["batting_team","venue"])["winner"].count()
# Out:
# batting_team         venue
# Chennai Super Kings  Arun Jaitley Stadium                                                     241
#                      Arun Jaitley Stadium, Delhi                                              371
#                      Barabati Stadium                                                         123
#                      Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    123
#                      Brabourne Stadium                                                        118
#                                                                                              ...
# Sunrisers Hyderabad  Sharjah Cricket Stadium                                                  818
#                      Sheikh Zayed Stadium                                                     745
#                      Wankhede Stadium                                                         873
# ...

# %%
a = full.groupby(["match_id","batter"])["total_runs"].sum()
b = full.groupby(["match_id","batter"])["total_runs"].count()
c=(a/b)*100
c.sort_values(ascending=False)
# Out:
# match_id  batter
# 734041    AP Tare       600.0
# 733979    R Bhatia      600.0
# 1254072   RA Jadeja     600.0
# 1304090   DR Sams       600.0
# 1359477   K Gowtham     600.0
#                         ...
# 392182    JD Ryder        0.0
# 335986    RT Ponting      0.0
#           VVS Laxman      0.0
#           WPUJC Vaas      0.0
# 1426309   TM Head         0.0
# Name: total_runs, Length: 16515, dtype: float64

# %%
full = pd.merge(df1,df2,left_on = "id",right_on = "match_id",how = "inner")

# %%
#Join matches and deliveries to find total balls bowled per match.
full.groupby("match_id")["total_runs"].count().sort_values(ascending = False)
# Out:
# match_id
# 1216517    269
# 392190     267
# 1426268    265
# 1082625    263
# 829737     262
#           ...
# 392183     108
# 829807     106
# 598068     100
# 501265      63
# 1178424     51
# Name: total_runs, Length: 1095, dtype: int64

# %%
#For each match, get total runs scored by joining matches and deliveries
#Find the top 10 highest-scoring matches.
full.groupby(["match_id","batting_team"])["total_runs"].sum().sort_values(ascending = False)
# Out:
# match_id  batting_team
# 1426268   Sunrisers Hyderabad            287
# 1422126   Sunrisers Hyderabad            277
# 1422134   Kolkata Knight Riders          272
# 1426273   Sunrisers Hyderabad            266
# 598027    Royal Challengers Bangalore    263
#                                         ...
# 1082617   Royal Challengers Bangalore     49
# 1082648   Kolkata Knight Riders           48
# 733993    Sunrisers Hyderabad             44
# 1178424   Rajasthan Royals                41
# 829813    Royal Challengers Bangalore      2
# Name: total_runs, Length: 2187, dtype: int64

# %%
#Find the number of wickets per match using join.
a = full[full["is_wicket"] == 1]
a.groupby("match_id")["is_wicket"].count().sort_values(ascending = False)
# Out:
# match_id
# 1082625    21
# 1082617    20
# 419141     20
# 1426289    20
# 1136583    20
#            ..
# 1426283     4
# 548337      4
# 501210      4
# 392211      4
# 501265      3
# Name: is_wicket, Length: 1095, dtype: int64

# %%
#List matches where more than 15 wides were bowled.
a = full[full["extras_type"] == "wides"].groupby("match_id")["extra_runs"].count().sort_values(ascending = False)
c = a[a>=15]
c
# Out:
# match_id
# 1426268    24
# 829737     20
# 1304076    19
# 1304049    19
# 548377     19
# 1359516    19
# 1426288    18
# 1426305    18
# 1422134    18
# 1426269    18
# 336018     18
# 1216522    18
# 1422119    17
# 1304084    17
# 1304098    16
# 829811     16
# 1359480    16
# 501221     16
# 1178423    16
# 392190     16
# 1254069    16
# 1304057    15
# 1304091    15
# 1426271    15
# 1426287    15
# 548367     15
# 1254084    15
# 829777     15
# 1304053    15
# 1312198    15
# 1216525    15
# 392218     15
# 1359529    15
# 419145     15
# 734019     15
# 1426292    15
# 829709     15
# Name: extra_runs, dtype: int64

# %%
# Find the player with the most deliveries faced across all matches.
full.groupby(["match_id","batter"])["total_runs"].count().sort_values(ascending =False)
# Out:
# match_id  batter
# 335982    BB McCullum    77
# 1422137   V Kohli        77
# 392236    MK Pandey      74
# 336019    SE Marsh       72
# 419131    DA Warner      72
#                          ..
# 1426305   Arshad Khan     1
# 501270    AT Rayudu       1
# 548315    R Bhatia        1
# 548312    SP Narine       1
# 548317    KD Karthik      1
# Name: total_runs, Length: 16515, dtype: int64

# %%
#Identify matches where total 6s > total 4s.
a= full[full["batsman_runs" ]== 4].groupby(["match_id"])["batsman_runs"].count()
b= full[full["batsman_runs" ]== 6].groupby(["match_id"])["batsman_runs"].count()
Abhi = pd.DataFrame({
    "total-4s" : a,
    "total-6s"  : b
})
c = Abhi[Abhi["total-4s"] < Abhi["total-6s"]]
c
# Out:
#           total-4s  total-6s
# match_id
# 548314          14        16
# 1082598         17        20
# 1082632         24        31
# 1136565         20        31
# 1136584         18        33
# 1216496         18        33
# 1216531         14        22
# 1254116         11        12
# 1304049         20        27
# 1304115         17        21
# 1359498         24        33
# 1359507         28        30
# 1422121         25        29
# 1422126         31        38
# 1422128         20        24
# 1422133         21        22
# 1426280         37        42

# %%
#For each match, find the highest scoring batsman in the last 5 overs.
a = full[full["over" ]>15]
b = a.groupby(["match_id","batter"])["total_runs"].sum().sort_values(ascending =False).reset_index()
b
# Out:
#       match_id        batter  total_runs
# 0       734005  Yuvraj Singh          62
# 1      1216510      KL Rahul          61
# 2      1136602       RR Pant          60
# 3       598060    KA Pollard          58
# 4       980987       V Kohli          58
# ...        ...           ...         ...
# 7370   1136587      DJ Bravo           0
# 7371   1136587       E Lewis           0
# 7372   1136589    AD Russell           0
# 7373   1136581     SV Samson           0
# 7374    336002    WPUJC Vaas           0
#
# [7375 rows x 3 columns]

# %%
#Get bowlers who delivered more than 100 balls in a season
a = full.groupby(["season","bowler"])["batsman_runs"].count()
b = a[a >100]
b
# Out:
# season   bowler
# 2007/08  A Kumble       236
#          A Mishra       123
#          A Nehra        280
#          AB Agarkar     168
#          AB Dinda       245
#                        ...
# 2024     UT Yadav       129
#          VG Arora       201
#          YS Chahal      362
#          Yash Dayal     322
#          Yash Thakur    225
# Name: batsman_runs, Length: 962, dtype: int64

# %%
#For each team, find wins where they scored more than 180 runs.
a = full.groupby(["match_id","winner"])["total_runs"].sum()
b = a[a>180]
b.reset_index().groupby("winner").size()
# Out:
# winner
# Chennai Super Kings            137
# Deccan Chargers                 29
# Delhi Capitals                  48
# Delhi Daredevils                66
# Gujarat Lions                   13
# Gujarat Titans                  28
# Kings XI Punjab                 87
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders          126
# Lucknow Super Giants            24
# Mumbai Indians                 143
# Pune Warriors                   12
# Punjab Kings                    24
# Rajasthan Royals               111
# Rising Pune Supergiant           9
# Rising Pune Supergiants          5
# Royal Challengers Bangalore    113
# Royal Challengers Bengaluru      7
# Sunrisers Hyderabad             86
# dtype: int64

# %%
#For each match, find the bowler who conceded most boundaries.
b = full[(full["batsman_runs"] == 4) |(full["batsman_runs"] == 6)]
a = b.groupby(["match_id","bowler"])["batsman_runs"].count()
a.sort_values(ascending = False)
# Out:
# match_id  bowler
# 1426281   L Wood            13
# 548380    VR Aaron          12
# 734047    P Awana           12
# 1422126   KT Maphaka        12
# 1216538   S Kaul            12
#                             ..
# 1304097   R Tewatia          1
# 1304094   LS Livingstone     1
#           R Dhawan           1
#           RD Chahar          1
# 1304095   JR Hazlewood       1
# Name: batsman_runs, Length: 12247, dtype: int64

# %%
#Identify matches where first innings score < 120 but team won.
a = full[full["inning"] == 1]
b = a.groupby(["match_id","winner"])["total_runs"].sum()
c = b[b<120]
c
# Out:
# match_id  winner
# 335986    Kolkata Knight Riders    110
# 336005    Rajasthan Royals         109
# 336008    Mumbai Indians           103
# 336021    Mumbai Indians            67
# 336022    Kings XI Punjab          118
#                                   ...
# 1304082   Sunrisers Hyderabad       68
# 1304105   Mumbai Indians            97
# 1359522   Gujarat Titans           118
# 1426270   Delhi Capitals            89
# 1426312   Kolkata Knight Riders    113
# Name: total_runs, Length: 80, dtype: int64

# %%
#For each season, find the total number of matches that went to the last over.
a = full[full["over"] >=19]
a.groupby(["season"])["match_id"].nunique()
# Out:
# season
# 2007/08    51
# 2009       55
# 2009/10    59
# 2011       67
# 2012       71
# 2013       75
# 2014       57
# 2015       55
# 2016       57
# 2017       56
# 2018       55
# 2019       58
# 2020/21    60
# 2021       59
# 2022       71
# 2023       73
# 2024       68
# Name: match_id, dtype: int64

# %%
#For each match, find total leg-byes conceded.
a = full[full["extras_type"] == "legbyes"]
a.groupby("match_id")["extra_runs"].sum()
# Out:
# match_id
# 335982     12
# 335983      6
# 335984      3
# 335985      6
# 335986     12
#            ..
# 1426307    11
# 1426309     9
# 1426310     3
# 1426311     2
# 1426312     4
# Name: extra_runs, Length: 1059, dtype: int64

# %%
full = pd.merge(df1,df2,left_on="id",right_on = "match_id",how="inner")

# %%
full
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...
